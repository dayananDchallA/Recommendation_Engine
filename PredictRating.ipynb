# %%
import numpy as np
import pandas as pd
import urllib
import io
import zipfile

# %%
# Download zip file
tmpFile = urllib.request.urlopen('https://www.librec.net/datasets/filmtrust.zip')

#Unzip the file
tmpFile = zipfile.ZipFile(io.BytesIO(tmpFile.read()))

# %%
#Open desired data file as pandas dataframe, close zipfile
dataset = pd.read_table(io.BytesIO(tmpFile.read('ratings.txt')),sep=' ',names=['uid','iid','rating'])
tmpFile.close()
dataset.head()
# Out:
#    uid  iid  rating
# 0    1    1     2.0
# 1    1    2     4.0
# 2    1    3     3.5
# 3    1    4     3.0
# 4    1    5     4.0

# %%
lower_rating = dataset['rating'].min()
upper_rating = dataset['rating'].max()
print('Review range: {0} to {1}'.format(lower_rating,upper_rating))
# Out:
# Review range: 0.5 to 4.0

# %%
import surprise
#So our review range goes from 0.5 to 4, which is a little non-standard (the default for surprise is 1-5). 
#So we will need to change this when we load in our dataset, which is done like this:
reader = surprise.Reader(rating_scale=(0.5,4.0))

# %%
data = surprise.Dataset.load_from_df(dataset,reader)

# %%
alg = surprise.SVDpp()
output = alg.fit(data.build_full_trainset())

# %%
#we can check the predicted score of, for example, user 50 on a music artist 52 using the predict method
pred = alg.predict(uid='50',iid='52')
score = pred.est
print(score)
# Out:
# 3.0028030537791928

# %%
#Let’s make our recommendations to a particular user. Let’s focus on uid 50 and find one item to recommend them

#Get list of all movie ids
iids = dataset['iid'].unique()

#Get list of movies that uid50 has rated
iids50 = dataset.loc[dataset['uid']==50,'iid']

#Remove the iids that uid50 has rated from the list of all movie iids
iids_to_pred = np.setdiff1d(iids,iids50)

# %%
#create another dataset with the iids we want to predict in the sparse format as before of: uid, iid, rating.

testset = [[50,iid,4.] for iid in iids_to_pred]
predictions = alg.test(testset)
predictions
# Out:
# [Prediction(uid=50, iid=14, r_ui=4.0, est=3.1300727028828383, details={'was_impossible': False}),
#  Prediction(uid=50, iid=15, r_ui=4.0, est=3.23537738475172, details={'was_impossible': False}),
#  Prediction(uid=50, iid=16, r_ui=4.0, est=3.5388115936896862, details={'was_impossible': False}),
#  Prediction(uid=50, iid=18, r_ui=4.0, est=3.5694397804620603, details={'was_impossible': False}),
#  Prediction(uid=50, iid=19, r_ui=4.0, est=3.436574935600214, details={'was_impossible': False}),
#  Prediction(uid=50, iid=20, r_ui=4.0, est=3.260456749689059, details={'was_impossible': False}),
#  Prediction(uid=50, iid=21, r_ui=4.0, est=3.246376746280475, details={'was_impossible': False}),
#  Prediction(uid=50, iid=22, r_ui=4.0, est=3.5466519140787143, details={'was_impossible': False}),
#  Prediction(uid=50, iid=23, r_ui=4.0, est=3.5452324500380024, details={'was_impossible': False}),
#  Prediction(uid=50, iid=24, r_ui=4.0, est=3.6704987821634965, details={'was_impossible': False}),
#  Prediction(uid=50, iid=25, r_ui=4.0, est=3.3822682292285875, details={'was_impossible': False}),
#  Prediction(uid=50, iid=26, r_ui=4.0, est=3.559230997691132, details={'was_impossible': False}),
#  Prediction(uid=50, iid=27, r_ui=4.0, est=3.661265627496943, details={'was_impossible': False}),
#  Prediction(uid=50, iid=28, r_ui=4.0, est=3.4913888819734797, details={'was_impossible': False}),
#  Prediction(uid=50, iid=29, r_ui=4.0, est=3.3767402458363005, details={'was_impossible': False}),
#  Prediction(uid=50, iid=30, r_ui=4.0, est=3.5014935296000904, details={'was_impossible': False}),
#  Prediction(uid=50, iid=31, r_ui=4.0, est=3.2823719512988796, details={'was_impossible': False}),
#  Prediction(uid=50, iid=32, r_ui=4.0, est=3.176470100823959, details={'was_impossible': False}),
#  Prediction(uid=50, iid=33, r_ui=4.0, est=3.5177115336051954, details={'was_impossible': False}),
#  Prediction(uid=50, iid=34, r_ui=4.0, est=3.424916495249612, details={'was_impossible': False}),
#  Prediction(uid=50, iid=35, r_ui=4.0, est=3.602286689198325, details={'was_impossible': False}),
#  Prediction(uid=50, iid=36, r_ui=4.0, est=3.0077453296858123, details={'was_impossible': False}),
#  Prediction(uid=50, iid=37, r_ui=4.0, est=3.5762937386346425, details={'was_impossible': False}),
#  Prediction(uid=50, iid=38, r_ui=4.0, est=3.3987120899938703, details={'was_impossible': False}),
#  Prediction(uid=50, iid=39, r_ui=4.0, est=3.509032894122195, details={'was_impossible': False}),
#  Prediction(uid=50, iid=40, r_ui=4.0, est=3.4808964283289274, details={'was_impossible': False}),
#  Prediction(uid=50, iid=41, r_ui=4.0, est=3.6255360829887024, details={'was_impossible': False}),
#  Prediction(uid=50, iid=42, r_ui=4.0, est=3.4078469015113537, details={'was_impossible': False}),
#  Prediction(uid=50, iid=43, r_ui=4.0, est=3.782144812490582, details={'was_impossible': False}),
#  Prediction(uid=50, iid=44, r_ui=4.0, est=3.6082776615681404, details={'was_impossible': False}),
#  Prediction(uid=50, iid=45, r_ui=4.0, est=3.3512550583024616, details={'was_impossible': False}),
#  Prediction(uid=50, iid=46, r_ui=4.0, est=3.1864928749449257, details={'was_impossible': False}),
#  Prediction(uid=50, iid=47, r_ui=4.0, est=3.278767585603403, details={'was_impossible': False}),
#  Prediction(uid=50, iid=48, r_ui=4.0, est=3.632813132174553, details={'was_impossible': False}),
#  Prediction(uid=50, iid=49, r_ui=4.0, est=3.4411067786781966, details={'was_impossible': False}),
#  Prediction(uid=50, iid=50, r_ui=4.0, est=3.580434542475891, details={'was_impossible': False}),
#  Prediction(uid=50, iid=51, r_ui=4.0, est=3.4231871848048785, details={'was_impossible': False}),
#  Prediction(uid=50, iid=52, r_ui=4.0, est=3.842231552579898, details={'was_impossible': False}),
#  Prediction(uid=50, iid=53, r_ui=4.0, est=3.536123350843342, details={'was_impossible': False}),
#  Prediction(uid=50, iid=54, r_ui=4.0, est=3.5662010502016046, details={'was_impossible': False}),
#  Prediction(uid=50, iid=55, r_ui=4.0, est=3.52032999482446, details={'was_impossible': False}),
#  Prediction(uid=50, iid=56, r_ui=4.0, est=3.4433341025880257, details={'was_impossible': False}),
#  Prediction(uid=50, iid=57, r_ui=4.0, est=3.289529984247725, details={'was_impossible': False}),
#  Prediction(uid=50, iid=58, r_ui=4.0, est=3.5913047763054355, details={'was_impossible': False}),
#  Prediction(uid=50, iid=59, r_ui=4.0, est=3.667180892652122, details={'was_impossible': False}),
#  Prediction(uid=50, iid=60, r_ui=4.0, est=3.504836607820087, details={'was_impossible': False}),
#  Prediction(uid=50, iid=61, r_ui=4.0, est=3.5310072635089127, details={'was_impossible': False}),
#  Prediction(uid=50, iid=62, r_ui=4.0, est=3.5494393715451573, details={'was_impossible': False}),
#  Prediction(uid=50, iid=63, r_ui=4.0, est=3.147632910251192, details={'was_impossible': False}),
#  Prediction(uid=50, iid=64, r_ui=4.0, est=3.565586955720797, details={'was_impossible': False}),
#  Prediction(uid=50, iid=65, r_ui=4.0, est=3.1936904131852906, details={'was_impossible': False}),
#  Prediction(uid=50, iid=66, r_ui=4.0, est=3.513616643156803, details={'was_impossible': False}),
#  Prediction(uid=50, iid=67, r_ui=4.0, est=3.2821975644270602, details={'was_impossible': False}),
#  Prediction(uid=50, iid=68, r_ui=4.0, est=3.907714438301586, details={'was_impossible': False}),
#  Prediction(uid=50, iid=69, r_ui=4.0, est=3.799460806274814, details={'was_impossible': False}),
#  Prediction(uid=50, iid=70, r_ui=4.0, est=2.9404939853104795, details={'was_impossible': False}),
#  Prediction(uid=50, iid=71, r_ui=4.0, est=3.6439441305131623, details={'was_impossible': False}),
#  Prediction(uid=50, iid=72, r_ui=4.0, est=3.4001514369647023, details={'was_impossible': False}),
#  Prediction(uid=50, iid=73, r_ui=4.0, est=3.3689639686678037, details={'was_impossible': False}),
#  Prediction(uid=50, iid=74, r_ui=4.0, est=3.4935049708334134, details={'was_impossible': False}),
#  Prediction(uid=50, iid=75, r_ui=4.0, est=3.497299076696921, details={'was_impossible': False}),
#  Prediction(uid=50, iid=76, r_ui=4.0, est=3.1750404947630577, details={'was_impossible': False}),
#  Prediction(uid=50, iid=77, r_ui=4.0, est=3.5145830004125314, details={'was_impossible': False}),
#  Prediction(uid=50, iid=78, r_ui=4.0, est=3.442817982723811, details={'was_impossible': False}),
#  Prediction(uid=50, iid=79, r_ui=4.0, est=3.4047175982913727, details={'was_impossible': False}),
#  Prediction(uid=50, iid=80, r_ui=4.0, est=3.3509157761908885, details={'was_impossible': False}),
#  Prediction(uid=50, iid=81, r_ui=4.0, est=3.6089776645865204, details={'was_impossible': False}),
#  Prediction(uid=50, iid=82, r_ui=4.0, est=3.544774123983532, details={'was_impossible': False}),
#  Prediction(uid=50, iid=83, r_ui=4.0, est=3.2679609172806536, details={'was_impossible': False}),
#  Prediction(uid=50, iid=85, r_ui=4.0, est=3.7540817281955863, details={'was_impossible': False}),
#  Prediction(uid=50, iid=86, r_ui=4.0, est=3.5600436022698347, details={'was_impossible': False}),
#  Prediction(uid=50, iid=87, r_ui=4.0, est=3.69858575110301, details={'was_impossible': False}),
#  Prediction(uid=50, iid=88, r_ui=4.0, est=3.287806366337981, details={'was_impossible': False}),
#  Prediction(uid=50, iid=89, r_ui=4.0, est=3.1665686339725387, details={'was_impossible': False}),
#  Prediction(uid=50, iid=90, r_ui=4.0, est=3.6125180648516633, details={'was_impossible': False}),
#  Prediction(uid=50, iid=91, r_ui=4.0, est=3.754718558765865, details={'was_impossible': False}),
#  Prediction(uid=50, iid=92, r_ui=4.0, est=3.2460747898483167, details={'was_impossible': False}),
#  Prediction(uid=50, iid=93, r_ui=4.0, est=3.4471570309340978, details={'was_impossible': False}),
#  Prediction(uid=50, iid=94, r_ui=4.0, est=3.567431487529652, details={'was_impossible': False}),
#  Prediction(uid=50, iid=95, r_ui=4.0, est=3.6184499745610377, details={'was_impossible': False}),
#  Prediction(uid=50, iid=96, r_ui=4.0, est=3.8451433378380733, details={'was_impossible': False}),
#  Prediction(uid=50, iid=97, r_ui=4.0, est=3.5841405688648673, details={'was_impossible': False}),
#  Prediction(uid=50, iid=98, r_ui=4.0, est=3.4530650635416986, details={'was_impossible': False}),
#  Prediction(uid=50, iid=99, r_ui=4.0, est=3.2432892394701094, details={'was_impossible': False}),
#  Prediction(uid=50, iid=100, r_ui=4.0, est=2.7643475789848218, details={'was_impossible': False}),
#  Prediction(uid=50, iid=101, r_ui=4.0, est=3.4719491334335304, details={'was_impossible': False}),
#  Prediction(uid=50, iid=102, r_ui=4.0, est=3.7151899478472474, details={'was_impossible': False}),
#  Prediction(uid=50, iid=103, r_ui=4.0, est=3.6553014945100677, details={'was_impossible': False}),
#  Prediction(uid=50, iid=104, r_ui=4.0, est=3.3273489043567452, details={'was_impossible': False}),
#  Prediction(uid=50, iid=105, r_ui=4.0, est=3.5960549539284705, details={'was_impossible': False}),
#  Prediction(uid=50, iid=106, r_ui=4.0, est=3.307471218782237, details={'was_impossible': False}),
#  Prediction(uid=50, iid=107, r_ui=4.0, est=3.683339453469302, details={'was_impossible': False}),
#  Prediction(uid=50, iid=108, r_ui=4.0, est=3.2396708441786064, details={'was_impossible': False}),
#  Prediction(uid=50, iid=109, r_ui=4.0, est=3.439121463214188, details={'was_impossible': False}),
#  Prediction(uid=50, iid=110, r_ui=4.0, est=3.7289124392072988, details={'was_impossible': False}),
#  Prediction(uid=50, iid=111, r_ui=4.0, est=3.5890606337875943, details={'was_impossible': False}),
#  Prediction(uid=50, iid=112, r_ui=4.0, est=3.6358201043050786, details={'was_impossible': False}),
#  Prediction(uid=50, iid=113, r_ui=4.0, est=3.003451089826564, details={'was_impossible': False}),
#  Prediction(uid=50, iid=114, r_ui=4.0, est=3.4432308288888493, details={'was_impossible': False}),
#  Prediction(uid=50, iid=115, r_ui=4.0, est=3.5272927390061897, details={'was_impossible': False}),
#  Prediction(uid=50, iid=116, r_ui=4.0, est=3.083223487546837, details={'was_impossible': False}),
#  Prediction(uid=50, iid=117, r_ui=4.0, est=3.6428054669045804, details={'was_impossible': False}),
#  Prediction(uid=50, iid=118, r_ui=4.0, est=3.719686849241412, details={'was_impossible': False}),
#  Prediction(uid=50, iid=119, r_ui=4.0, est=3.299133128700552, details={'was_impossible': False}),
#  Prediction(uid=50, iid=120, r_ui=4.0, est=3.5047888649990053, details={'was_impossible': False}),
#  Prediction(uid=50, iid=122, r_ui=4.0, est=3.358030099521081, details={'was_impossible': False}),
#  Prediction(uid=50, iid=123, r_ui=4.0, est=3.543476695645942, details={'was_impossible': False}),
#  Prediction(uid=50, iid=124, r_ui=4.0, est=3.294634559029293, details={'was_impossible': False}),
#  Prediction(uid=50, iid=125, r_ui=4.0, est=3.127450946742603, details={'was_impossible': False}),
#  Prediction(uid=50, iid=126, r_ui=4.0, est=3.9158108258373368, details={'was_impossible': False}),
#  Prediction(uid=50, iid=127, r_ui=4.0, est=3.3833446105472653, details={'was_impossible': False}),
#  Prediction(uid=50, iid=128, r_ui=4.0, est=3.2611454925606083, details={'was_impossible': False}),
#  Prediction(uid=50, iid=129, r_ui=4.0, est=3.5330350624630227, details={'was_impossible': False}),
#  Prediction(uid=50, iid=130, r_ui=4.0, est=3.3450797033043393, details={'was_impossible': False}),
#  Prediction(uid=50, iid=131, r_ui=4.0, est=3.373838806710826, details={'was_impossible': False}),
#  Prediction(uid=50, iid=132, r_ui=4.0, est=3.770473875887414, details={'was_impossible': False}),
#  Prediction(uid=50, iid=133, r_ui=4.0, est=3.547972383084315, details={'was_impossible': False}),
#  Prediction(uid=50, iid=134, r_ui=4.0, est=3.5824528777851326, details={'was_impossible': False}),
#  Prediction(uid=50, iid=135, r_ui=4.0, est=3.306174459509036, details={'was_impossible': False}),
#  Prediction(uid=50, iid=136, r_ui=4.0, est=3.642925909231033, details={'was_impossible': False}),
#  Prediction(uid=50, iid=137, r_ui=4.0, est=3.334973697075711, details={'was_impossible': False}),
#  Prediction(uid=50, iid=138, r_ui=4.0, est=3.4226676103108673, details={'was_impossible': False}),
#  Prediction(uid=50, iid=139, r_ui=4.0, est=3.5542125075109, details={'was_impossible': False}),
#  Prediction(uid=50, iid=140, r_ui=4.0, est=3.483651164571341, details={'was_impossible': False}),
#  Prediction(uid=50, iid=141, r_ui=4.0, est=3.560154364624272, details={'was_impossible': False}),
#  Prediction(uid=50, iid=142, r_ui=4.0, est=3.783790415050468, details={'was_impossible': False}),
#  Prediction(uid=50, iid=143, r_ui=4.0, est=3.381795135517184, details={'was_impossible': False}),
#  Prediction(uid=50, iid=144, r_ui=4.0, est=3.895521643210326, details={'was_impossible': False}),
#  Prediction(uid=50, iid=145, r_ui=4.0, est=3.6020317370055084, details={'was_impossible': False}),
#  Prediction(uid=50, iid=146, r_ui=4.0, est=3.3032180834696963, details={'was_impossible': False}),
#  Prediction(uid=50, iid=147, r_ui=4.0, est=3.6736993944373464, details={'was_impossible': False}),
#  Prediction(uid=50, iid=148, r_ui=4.0, est=3.6404518823897027, details={'was_impossible': False}),
#  Prediction(uid=50, iid=149, r_ui=4.0, est=3.3340315217258114, details={'was_impossible': False}),
#  Prediction(uid=50, iid=150, r_ui=4.0, est=3.603388172708586, details={'was_impossible': False}),
#  Prediction(uid=50, iid=151, r_ui=4.0, est=3.5562402933472685, details={'was_impossible': False}),
#  Prediction(uid=50, iid=152, r_ui=4.0, est=3.593032076013922, details={'was_impossible': False}),
#  Prediction(uid=50, iid=153, r_ui=4.0, est=3.3875561411243162, details={'was_impossible': False}),
#  Prediction(uid=50, iid=154, r_ui=4.0, est=3.390362129601949, details={'was_impossible': False}),
#  Prediction(uid=50, iid=155, r_ui=4.0, est=3.514594390419146, details={'was_impossible': False}),
#  Prediction(uid=50, iid=156, r_ui=4.0, est=2.9848798715090608, details={'was_impossible': False}),
#  Prediction(uid=50, iid=157, r_ui=4.0, est=3.3964172507379424, details={'was_impossible': False}),
#  Prediction(uid=50, iid=158, r_ui=4.0, est=3.3244398415200758, details={'was_impossible': False}),
#  Prediction(uid=50, iid=159, r_ui=4.0, est=3.1398625605153496, details={'was_impossible': False}),
#  Prediction(uid=50, iid=160, r_ui=4.0, est=3.409781405677052, details={'was_impossible': False}),
#  Prediction(uid=50, iid=161, r_ui=4.0, est=3.5479192745029677, details={'was_impossible': False}),
#  Prediction(uid=50, iid=162, r_ui=4.0, est=3.6489772177189184, details={'was_impossible': False}),
#  Prediction(uid=50, iid=163, r_ui=4.0, est=3.2646595846097104, details={'was_impossible': False}),
#  Prediction(uid=50, iid=164, r_ui=4.0, est=3.506998417004117, details={'was_impossible': False}),
#  Prediction(uid=50, iid=165, r_ui=4.0, est=3.5684315159491495, details={'was_impossible': False}),
#  Prediction(uid=50, iid=166, r_ui=4.0, est=3.3961809254097735, details={'was_impossible': False}),
#  Prediction(uid=50, iid=167, r_ui=4.0, est=3.8584899421124192, details={'was_impossible': False}),
#  Prediction(uid=50, iid=168, r_ui=4.0, est=3.623587997500976, details={'was_impossible': False}),
#  Prediction(uid=50, iid=169, r_ui=4.0, est=2.8629329126317735, details={'was_impossible': False}),
#  Prediction(uid=50, iid=170, r_ui=4.0, est=3.254110938052489, details={'was_impossible': False}),
#  Prediction(uid=50, iid=171, r_ui=4.0, est=3.184156274287351, details={'was_impossible': False}),
#  Prediction(uid=50, iid=172, r_ui=4.0, est=3.341465491592917, details={'was_impossible': False}),
#  Prediction(uid=50, iid=173, r_ui=4.0, est=3.24261122421599, details={'was_impossible': False}),
#  Prediction(uid=50, iid=174, r_ui=4.0, est=3.6740155732681923, details={'was_impossible': False}),
#  Prediction(uid=50, iid=175, r_ui=4.0, est=3.141064218243862, details={'was_impossible': False}),
#  Prediction(uid=50, iid=176, r_ui=4.0, est=3.366340476113491, details={'was_impossible': False}),
#  Prediction(uid=50, iid=177, r_ui=4.0, est=3.572870010301725, details={'was_impossible': False}),
#  Prediction(uid=50, iid=178, r_ui=4.0, est=3.6464808536090003, details={'was_impossible': False}),
#  Prediction(uid=50, iid=179, r_ui=4.0, est=3.118373432567366, details={'was_impossible': False}),
#  Prediction(uid=50, iid=180, r_ui=4.0, est=3.3527443231504894, details={'was_impossible': False}),
#  Prediction(uid=50, iid=181, r_ui=4.0, est=3.822318095190786, details={'was_impossible': False}),
#  Prediction(uid=50, iid=182, r_ui=4.0, est=3.555577718490113, details={'was_impossible': False}),
#  Prediction(uid=50, iid=183, r_ui=4.0, est=3.3183033873613157, details={'was_impossible': False}),
#  Prediction(uid=50, iid=184, r_ui=4.0, est=3.1132081564179956, details={'was_impossible': False}),
#  Prediction(uid=50, iid=185, r_ui=4.0, est=3.5455066933552732, details={'was_impossible': False}),
#  Prediction(uid=50, iid=186, r_ui=4.0, est=3.6176694533989093, details={'was_impossible': False}),
#  Prediction(uid=50, iid=187, r_ui=4.0, est=3.7391274743248832, details={'was_impossible': False}),
#  Prediction(uid=50, iid=188, r_ui=4.0, est=3.6574311194384204, details={'was_impossible': False}),
#  Prediction(uid=50, iid=189, r_ui=4.0, est=3.958886777131231, details={'was_impossible': False}),
#  Prediction(uid=50, iid=190, r_ui=4.0, est=3.538792439696078, details={'was_impossible': False}),
#  Prediction(uid=50, iid=191, r_ui=4.0, est=3.5598261486361267, details={'was_impossible': False}),
#  Prediction(uid=50, iid=192, r_ui=4.0, est=3.643103732861504, details={'was_impossible': False}),
#  Prediction(uid=50, iid=193, r_ui=4.0, est=3.570151360314337, details={'was_impossible': False}),
#  Prediction(uid=50, iid=194, r_ui=4.0, est=3.2564729162036397, details={'was_impossible': False}),
#  Prediction(uid=50, iid=195, r_ui=4.0, est=3.225065455710789, details={'was_impossible': False}),
#  Prediction(uid=50, iid=196, r_ui=4.0, est=3.4125190539329004, details={'was_impossible': False}),
#  Prediction(uid=50, iid=197, r_ui=4.0, est=3.850358799780626, details={'was_impossible': False}),
#  Prediction(uid=50, iid=198, r_ui=4.0, est=3.461427826346338, details={'was_impossible': False}),
#  Prediction(uid=50, iid=199, r_ui=4.0, est=3.4761277081209427, details={'was_impossible': False}),
#  Prediction(uid=50, iid=200, r_ui=4.0, est=3.3368324745919327, details={'was_impossible': False}),
#  Prediction(uid=50, iid=201, r_ui=4.0, est=3.4512509460647554, details={'was_impossible': False}),
#  Prediction(uid=50, iid=202, r_ui=4.0, est=3.5727276142069986, details={'was_impossible': False}),
#  Prediction(uid=50, iid=203, r_ui=4.0, est=3.361372305103589, details={'was_impossible': False}),
#  Prediction(uid=50, iid=204, r_ui=4.0, est=3.624133534901474, details={'was_impossible': False}),
#  Prediction(uid=50, iid=205, r_ui=4.0, est=3.3895176099529327, details={'was_impossible': False}),
#  Prediction(uid=50, iid=208, r_ui=4.0, est=3.1975741743706245, details={'was_impossible': False}),
#  Prediction(uid=50, iid=209, r_ui=4.0, est=3.409229127293855, details={'was_impossible': False}),
#  Prediction(uid=50, iid=210, r_ui=4.0, est=3.2710915067243915, details={'was_impossible': False}),
#  Prediction(uid=50, iid=212, r_ui=4.0, est=3.3946655802884247, details={'was_impossible': False}),
#  Prediction(uid=50, iid=214, r_ui=4.0, est=3.4091873777798987, details={'was_impossible': False}),
#  Prediction(uid=50, iid=218, r_ui=4.0, est=3.9693854581716663, details={'was_impossible': False}),
#  Prediction(uid=50, iid=221, r_ui=4.0, est=3.330323976489049, details={'was_impossible': False}),
#  Prediction(uid=50, iid=222, r_ui=4.0, est=3.669931542974419, details={'was_impossible': False}),
#  Prediction(uid=50, iid=223, r_ui=4.0, est=3.6734506946690058, details={'was_impossible': False}),
#  Prediction(uid=50, iid=224, r_ui=4.0, est=3.207507489480525, details={'was_impossible': False}),
#  Prediction(uid=50, iid=225, r_ui=4.0, est=3.2508407481608064, details={'was_impossible': False}),
#  Prediction(uid=50, iid=226, r_ui=4.0, est=3.529104608434808, details={'was_impossible': False}),
#  Prediction(uid=50, iid=227, r_ui=4.0, est=3.51435498450759, details={'was_impossible': False}),
#  Prediction(uid=50, iid=228, r_ui=4.0, est=3.668196970620653, details={'was_impossible': False}),
#  Prediction(uid=50, iid=229, r_ui=4.0, est=3.2390948019339088, details={'was_impossible': False}),
#  Prediction(uid=50, iid=230, r_ui=4.0, est=3.625977090573058, details={'was_impossible': False}),
#  Prediction(uid=50, iid=231, r_ui=4.0, est=3.267738287634032, details={'was_impossible': False}),
#  Prediction(uid=50, iid=232, r_ui=4.0, est=3.520995482835436, details={'was_impossible': False}),
#  Prediction(uid=50, iid=237, r_ui=4.0, est=3.213383192299918, details={'was_impossible': False}),
#  Prediction(uid=50, iid=238, r_ui=4.0, est=3.3691043974832424, details={'was_impossible': False}),
#  Prediction(uid=50, iid=240, r_ui=4.0, est=3.3080125620863097, details={'was_impossible': False}),
#  Prediction(uid=50, iid=242, r_ui=4.0, est=3.9203281051958245, details={'was_impossible': False}),
#  Prediction(uid=50, iid=243, r_ui=4.0, est=2.8102098294261677, details={'was_impossible': False}),
#  Prediction(uid=50, iid=244, r_ui=4.0, est=3.323458848796442, details={'was_impossible': False}),
#  Prediction(uid=50, iid=246, r_ui=4.0, est=3.542683111533304, details={'was_impossible': False}),
#  Prediction(uid=50, iid=247, r_ui=4.0, est=3.480263254757946, details={'was_impossible': False}),
#  Prediction(uid=50, iid=248, r_ui=4.0, est=3.1677230745869123, details={'was_impossible': False}),
#  Prediction(uid=50, iid=249, r_ui=4.0, est=3.3514792264598112, details={'was_impossible': False}),
#  Prediction(uid=50, iid=256, r_ui=4.0, est=3.3227374444049924, details={'was_impossible': False}),
#  Prediction(uid=50, iid=258, r_ui=4.0, est=3.637257902194291, details={'was_impossible': False}),
#  Prediction(uid=50, iid=259, r_ui=4.0, est=3.559781223983067, details={'was_impossible': False}),
#  Prediction(uid=50, iid=260, r_ui=4.0, est=3.260527017132884, details={'was_impossible': False}),
#  Prediction(uid=50, iid=261, r_ui=4.0, est=3.6097231733050696, details={'was_impossible': False}),
#  Prediction(uid=50, iid=262, r_ui=4.0, est=3.4235499743389854, details={'was_impossible': False}),
#  Prediction(uid=50, iid=263, r_ui=4.0, est=3.004404321750525, details={'was_impossible': False}),
#  Prediction(uid=50, iid=264, r_ui=4.0, est=3.33179507486804, details={'was_impossible': False}),
#  Prediction(uid=50, iid=265, r_ui=4.0, est=3.405755412812084, details={'was_impossible': False}),
#  Prediction(uid=50, iid=266, r_ui=4.0, est=3.146721949202609, details={'was_impossible': False}),
#  Prediction(uid=50, iid=267, r_ui=4.0, est=3.25758270792943, details={'was_impossible': False}),
#  Prediction(uid=50, iid=268, r_ui=4.0, est=3.7041413399897496, details={'was_impossible': False}),
#  Prediction(uid=50, iid=269, r_ui=4.0, est=3.7134779774490325, details={'was_impossible': False}),
#  Prediction(uid=50, iid=270, r_ui=4.0, est=3.4390413391215966, details={'was_impossible': False}),
#  Prediction(uid=50, iid=271, r_ui=4.0, est=3.5029727131507666, details={'was_impossible': False}),
#  Prediction(uid=50, iid=272, r_ui=4.0, est=3.518239049031321, details={'was_impossible': False}),
#  Prediction(uid=50, iid=273, r_ui=4.0, est=3.34800292430107, details={'was_impossible': False}),
#  Prediction(uid=50, iid=274, r_ui=4.0, est=3.2069048206033575, details={'was_impossible': False}),
#  Prediction(uid=50, iid=275, r_ui=4.0, est=3.7355659564632946, details={'was_impossible': False}),
#  Prediction(uid=50, iid=276, r_ui=4.0, est=3.443459911162431, details={'was_impossible': False}),
#  Prediction(uid=50, iid=277, r_ui=4.0, est=3.1052798126683765, details={'was_impossible': False}),
#  Prediction(uid=50, iid=278, r_ui=4.0, est=3.7654175905962584, details={'was_impossible': False}),
#  Prediction(uid=50, iid=279, r_ui=4.0, est=3.70196009303851, details={'was_impossible': False}),
#  Prediction(uid=50, iid=280, r_ui=4.0, est=3.258878677021375, details={'was_impossible': False}),
#  Prediction(uid=50, iid=281, r_ui=4.0, est=3.5931614874742785, details={'was_impossible': False}),
#  Prediction(uid=50, iid=282, r_ui=4.0, est=3.3460750062729288, details={'was_impossible': False}),
#  Prediction(uid=50, iid=283, r_ui=4.0, est=3.07176659692632, details={'was_impossible': False}),
#  Prediction(uid=50, iid=284, r_ui=4.0, est=3.4713080579063393, details={'was_impossible': False}),
#  Prediction(uid=50, iid=285, r_ui=4.0, est=3.4613092203857425, details={'was_impossible': False}),
#  Prediction(uid=50, iid=286, r_ui=4.0, est=4.0, details={'was_impossible': False}),
#  Prediction(uid=50, iid=287, r_ui=4.0, est=3.573498008932314, details={'was_impossible': False}),
#  Prediction(uid=50, iid=288, r_ui=4.0, est=3.4988193083752663, details={'was_impossible': False}),
#  Prediction(uid=50, iid=289, r_ui=4.0, est=3.5123621354762515, details={'was_impossible': False}),
#  Prediction(uid=50, iid=290, r_ui=4.0, est=3.832666757118503, details={'was_impossible': False}),
#  Prediction(uid=50, iid=291, r_ui=4.0, est=3.729076363179935, details={'was_impossible': False}),
#  Prediction(uid=50, iid=292, r_ui=4.0, est=3.7759188073144316, details={'was_impossible': False}),
#  Prediction(uid=50, iid=293, r_ui=4.0, est=3.803306363489124, details={'was_impossible': False}),
#  Prediction(uid=50, iid=294, r_ui=4.0, est=3.709390535871307, details={'was_impossible': False}),
#  Prediction(uid=50, iid=295, r_ui=4.0, est=3.630334543057158, details={'was_impossible': False}),
#  Prediction(uid=50, iid=296, r_ui=4.0, est=3.429716691222264, details={'was_impossible': False}),
#  Prediction(uid=50, iid=297, r_ui=4.0, est=3.9573628772925153, details={'was_impossible': False}),
#  Prediction(uid=50, iid=298, r_ui=4.0, est=3.724572591170561, details={'was_impossible': False}),
#  Prediction(uid=50, iid=299, r_ui=4.0, est=3.9412719050436618, details={'was_impossible': False}),
#  Prediction(uid=50, iid=300, r_ui=4.0, est=3.5754387949634996, details={'was_impossible': False}),
#  Prediction(uid=50, iid=301, r_ui=4.0, est=3.175547501552904, details={'was_impossible': False}),
#  Prediction(uid=50, iid=302, r_ui=4.0, est=3.7837523630019922, details={'was_impossible': False}),
#  Prediction(uid=50, iid=303, r_ui=4.0, est=3.5024980034371147, details={'was_impossible': False}),
#  Prediction(uid=50, iid=304, r_ui=4.0, est=3.735913125283972, details={'was_impossible': False}),
#  Prediction(uid=50, iid=305, r_ui=4.0, est=3.3675039959056954, details={'was_impossible': False}),
#  Prediction(uid=50, iid=306, r_ui=4.0, est=3.6382394823144093, details={'was_impossible': False}),
#  Prediction(uid=50, iid=307, r_ui=4.0, est=4.0, details={'was_impossible': False}),
#  Prediction(uid=50, iid=308, r_ui=4.0, est=3.85653407036151, details={'was_impossible': False}),
#  Prediction(uid=50, iid=309, r_ui=4.0, est=3.7835567152602816, details={'was_impossible': False}),
#  Prediction(uid=50, iid=310, r_ui=4.0, est=3.7311410583931046, details={'was_impossible': False}),
#  Prediction(uid=50, iid=311, r_ui=4.0, est=3.7404301378140126, details={'was_impossible': False}),
#  Prediction(uid=50, iid=312, r_ui=4.0, est=3.7552736730543637, details={'was_impossible': False}),
#  Prediction(uid=50, iid=313, r_ui=4.0, est=3.547647647831979, details={'was_impossible': False}),
#  Prediction(uid=50, iid=314, r_ui=4.0, est=3.4809108641517295, details={'was_impossible': False}),
#  Prediction(uid=50, iid=315, r_ui=4.0, est=3.8535655716276698, details={'was_impossible': False}),
#  Prediction(uid=50, iid=316, r_ui=4.0, est=3.9066236001378547, details={'was_impossible': False}),
#  Prediction(uid=50, iid=317, r_ui=4.0, est=3.3395486999735478, details={'was_impossible': False}),
#  Prediction(uid=50, iid=318, r_ui=4.0, est=3.7776943532657823, details={'was_impossible': False}),
#  Prediction(uid=50, iid=319, r_ui=4.0, est=3.7313311608023363, details={'was_impossible': False}),
#  Prediction(uid=50, iid=320, r_ui=4.0, est=3.593909281817899, details={'was_impossible': False}),
#  Prediction(uid=50, iid=321, r_ui=4.0, est=3.286283900799407, details={'was_impossible': False}),
#  Prediction(uid=50, iid=322, r_ui=4.0, est=3.598759686721409, details={'was_impossible': False}),
#  Prediction(uid=50, iid=323, r_ui=4.0, est=3.2791100893515908, details={'was_impossible': False}),
#  Prediction(uid=50, iid=324, r_ui=4.0, est=3.2933600249469177, details={'was_impossible': False}),
#  Prediction(uid=50, iid=325, r_ui=4.0, est=3.4503787940890454, details={'was_impossible': False}),
#  Prediction(uid=50, iid=326, r_ui=4.0, est=2.9514344763580316, details={'was_impossible': False}),
#  Prediction(uid=50, iid=327, r_ui=4.0, est=3.240394663071294, details={'was_impossible': False}),
#  Prediction(uid=50, iid=328, r_ui=4.0, est=3.482491192831633, details={'was_impossible': False}),
#  Prediction(uid=50, iid=329, r_ui=4.0, est=3.5928516905829486, details={'was_impossible': False}),
#  Prediction(uid=50, iid=330, r_ui=4.0, est=3.299850586498949, details={'was_impossible': False}),
#  Prediction(uid=50, iid=331, r_ui=4.0, est=3.5062734860341376, details={'was_impossible': False}),
#  Prediction(uid=50, iid=332, r_ui=4.0, est=3.5864265875222503, details={'was_impossible': False}),
#  Prediction(uid=50, iid=333, r_ui=4.0, est=3.3140210734115767, details={'was_impossible': False}),
#  Prediction(uid=50, iid=334, r_ui=4.0, est=3.3770088831181844, details={'was_impossible': False}),
#  Prediction(uid=50, iid=335, r_ui=4.0, est=4.0, details={'was_impossible': False}),
#  Prediction(uid=50, iid=336, r_ui=4.0, est=3.740550816021282, details={'was_impossible': False}),
#  Prediction(uid=50, iid=337, r_ui=4.0, est=3.4889654036199884, details={'was_impossible': False}),
#  Prediction(uid=50, iid=338, r_ui=4.0, est=3.756437451027896, details={'was_impossible': False}),
#  Prediction(uid=50, iid=339, r_ui=4.0, est=3.5223394821201723, details={'was_impossible': False}),
#  Prediction(uid=50, iid=340, r_ui=4.0, est=3.709496888009331, details={'was_impossible': False}),
#  Prediction(uid=50, iid=341, r_ui=4.0, est=3.032457038062643, details={'was_impossible': False}),
#  Prediction(uid=50, iid=342, r_ui=4.0, est=3.840600582062289, details={'was_impossible': False}),
#  Prediction(uid=50, iid=343, r_ui=4.0, est=3.8211449640934623, details={'was_impossible': False}),
#  Prediction(uid=50, iid=344, r_ui=4.0, est=3.851204713086268, details={'was_impossible': False}),
#  Prediction(uid=50, iid=345, r_ui=4.0, est=3.545236914401267, details={'was_impossible': False}),
#  Prediction(uid=50, iid=346, r_ui=4.0, est=3.4597797459099007, details={'was_impossible': False}),
#  Prediction(uid=50, iid=347, r_ui=4.0, est=3.9323493999567787, details={'was_impossible': False}),
#  Prediction(uid=50, iid=348, r_ui=4.0, est=3.6833292730898135, details={'was_impossible': False}),
#  Prediction(uid=50, iid=349, r_ui=4.0, est=3.5706702873843024, details={'was_impossible': False}),
#  Prediction(uid=50, iid=350, r_ui=4.0, est=3.4240408445495296, details={'was_impossible': False}),
#  Prediction(uid=50, iid=351, r_ui=4.0, est=2.9955961838707568, details={'was_impossible': False}),
#  Prediction(uid=50, iid=352, r_ui=4.0, est=3.474951094704682, details={'was_impossible': False}),
#  Prediction(uid=50, iid=353, r_ui=4.0, est=3.5087466871396114, details={'was_impossible': False}),
#  Prediction(uid=50, iid=354, r_ui=4.0, est=3.17172430067007, details={'was_impossible': False}),
#  Prediction(uid=50, iid=355, r_ui=4.0, est=3.646640918250629, details={'was_impossible': False}),
#  Prediction(uid=50, iid=356, r_ui=4.0, est=3.3581976823831137, details={'was_impossible': False}),
#  Prediction(uid=50, iid=357, r_ui=4.0, est=3.475893998131864, details={'was_impossible': False}),
#  Prediction(uid=50, iid=358, r_ui=4.0, est=3.445364614356493, details={'was_impossible': False}),
#  Prediction(uid=50, iid=359, r_ui=4.0, est=3.508653982973402, details={'was_impossible': False}),
#  Prediction(uid=50, iid=360, r_ui=4.0, est=3.5202104429482963, details={'was_impossible': False}),
#  Prediction(uid=50, iid=361, r_ui=4.0, est=3.16548347205471, details={'was_impossible': False}),
#  Prediction(uid=50, iid=362, r_ui=4.0, est=3.707989356842901, details={'was_impossible': False}),
#  Prediction(uid=50, iid=363, r_ui=4.0, est=4.0, details={'was_impossible': False}),
#  Prediction(uid=50, iid=364, r_ui=4.0, est=3.0001802480314623, details={'was_impossible': False}),
#  Prediction(uid=50, iid=365, r_ui=4.0, est=3.9478425590855, details={'was_impossible': False}),
#  Prediction(uid=50, iid=366, r_ui=4.0, est=3.482557314537238, details={'was_impossible': False}),
#  Prediction(uid=50, iid=367, r_ui=4.0, est=3.659449343129165, details={'was_impossible': False}),
#  Prediction(uid=50, iid=368, r_ui=4.0, est=3.671743741924271, details={'was_impossible': False}),
#  Prediction(uid=50, iid=369, r_ui=4.0, est=3.5128516894234747, details={'was_impossible': False}),
#  Prediction(uid=50, iid=370, r_ui=4.0, est=3.569162505103771, details={'was_impossible': False}),
#  Prediction(uid=50, iid=371, r_ui=4.0, est=3.5952043611519855, details={'was_impossible': False}),
#  Prediction(uid=50, iid=372, r_ui=4.0, est=3.550360121741715, details={'was_impossible': False}),
#  Prediction(uid=50, iid=373, r_ui=4.0, est=3.430943047544258, details={'was_impossible': False}),
#  Prediction(uid=50, iid=374, r_ui=4.0, est=3.512890339346894, details={'was_impossible': False}),
#  Prediction(uid=50, iid=375, r_ui=4.0, est=3.3633896261869993, details={'was_impossible': False}),
#  Prediction(uid=50, iid=376, r_ui=4.0, est=3.526744863616331, details={'was_impossible': False}),
#  Prediction(uid=50, iid=377, r_ui=4.0, est=3.582939558714254, details={'was_impossible': False}),
#  Prediction(uid=50, iid=378, r_ui=4.0, est=3.3137394214887745, details={'was_impossible': False}),
#  Prediction(uid=50, iid=379, r_ui=4.0, est=3.4622517062818163, details={'was_impossible': False}),
#  Prediction(uid=50, iid=380, r_ui=4.0, est=3.5718667427445974, details={'was_impossible': False}),
#  Prediction(uid=50, iid=381, r_ui=4.0, est=3.1167127718403997, details={'was_impossible': False}),
#  Prediction(uid=50, iid=382, r_ui=4.0, est=3.329324382711636, details={'was_impossible': False}),
#  Prediction(uid=50, iid=383, r_ui=4.0, est=3.0036136674770852, details={'was_impossible': False}),
#  Prediction(uid=50, iid=384, r_ui=4.0, est=3.654363122294094, details={'was_impossible': False}),
#  Prediction(uid=50, iid=385, r_ui=4.0, est=3.095284069855886, details={'was_impossible': False}),
#  Prediction(uid=50, iid=386, r_ui=4.0, est=3.3138338011392383, details={'was_impossible': False}),
#  Prediction(uid=50, iid=387, r_ui=4.0, est=3.144559134541939, details={'was_impossible': False}),
#  Prediction(uid=50, iid=388, r_ui=4.0, est=3.371210807034213, details={'was_impossible': False}),
#  Prediction(uid=50, iid=389, r_ui=4.0, est=3.0166846678667825, details={'was_impossible': False}),
#  Prediction(uid=50, iid=390, r_ui=4.0, est=3.557484008890958, details={'was_impossible': False}),
#  Prediction(uid=50, iid=391, r_ui=4.0, est=3.9474473770935856, details={'was_impossible': False}),
#  Prediction(uid=50, iid=392, r_ui=4.0, est=3.6753468146944575, details={'was_impossible': False}),
#  Prediction(uid=50, iid=393, r_ui=4.0, est=3.8909787899575283, details={'was_impossible': False}),
#  Prediction(uid=50, iid=394, r_ui=4.0, est=3.521542280568153, details={'was_impossible': False}),
#  Prediction(uid=50, iid=395, r_ui=4.0, est=3.3669581821884025, details={'was_impossible': False}),
#  Prediction(uid=50, iid=396, r_ui=4.0, est=3.8024666939031775, details={'was_impossible': False}),
#  Prediction(uid=50, iid=397, r_ui=4.0, est=3.7669892687057347, details={'was_impossible': False}),
#  Prediction(uid=50, iid=398, r_ui=4.0, est=4.0, details={'was_impossible': False}),
#  Prediction(uid=50, iid=399, r_ui=4.0, est=3.9341579157526936, details={'was_impossible': False}),
#  Prediction(uid=50, iid=400, r_ui=4.0, est=3.9032993710229436, details={'was_impossible': False}),
#  Prediction(uid=50, iid=401, r_ui=4.0, est=3.6025331478443716, details={'was_impossible': False}),
#  Prediction(uid=50, iid=402, r_ui=4.0, est=3.427776521895363, details={'was_impossible': False}),
#  Prediction(uid=50, iid=403, r_ui=4.0, est=3.4920512870594775, details={'was_impossible': False}),
#  Prediction(uid=50, iid=404, r_ui=4.0, est=3.32913641496309, details={'was_impossible': False}),
#  Prediction(uid=50, iid=405, r_ui=4.0, est=3.917539611350779, details={'was_impossible': False}),
#  Prediction(uid=50, iid=406, r_ui=4.0, est=3.641025227637166, details={'was_impossible': False}),
#  Prediction(uid=50, iid=407, r_ui=4.0, est=3.210049976291355, details={'was_impossible': False}),
#  Prediction(uid=50, iid=408, r_ui=4.0, est=3.8343076135884537, details={'was_impossible': False}),
#  Prediction(uid=50, iid=409, r_ui=4.0, est=3.2167854005640217, details={'was_impossible': False}),
#  Prediction(uid=50, iid=410, r_ui=4.0, est=3.454067114118906, details={'was_impossible': False}),
#  Prediction(uid=50, iid=411, r_ui=4.0, est=3.8214490247882873, details={'was_impossible': False}),
#  Prediction(uid=50, iid=412, r_ui=4.0, est=3.725679437293012, details={'was_impossible': False}),
#  Prediction(uid=50, iid=413, r_ui=4.0, est=3.384387156837735, details={'was_impossible': False}),
#  Prediction(uid=50, iid=414, r_ui=4.0, est=3.9572958014367607, details={'was_impossible': False}),
#  Prediction(uid=50, iid=415, r_ui=4.0, est=3.923101934045992, details={'was_impossible': False}),
#  Prediction(uid=50, iid=416, r_ui=4.0, est=3.273560251198477, details={'was_impossible': False}),
#  Prediction(uid=50, iid=417, r_ui=4.0, est=3.6292669535467654, details={'was_impossible': False}),
#  Prediction(uid=50, iid=418, r_ui=4.0, est=3.212505151412498, details={'was_impossible': False}),
#  Prediction(uid=50, iid=419, r_ui=4.0, est=3.6031978562159725, details={'was_impossible': False}),
#  Prediction(uid=50, iid=420, r_ui=4.0, est=3.357115575228042, details={'was_impossible': False}),
#  Prediction(uid=50, iid=421, r_ui=4.0, est=3.672732644783029, details={'was_impossible': False}),
#  Prediction(uid=50, iid=422, r_ui=4.0, est=3.2397274173340596, details={'was_impossible': False}),
#  Prediction(uid=50, iid=423, r_ui=4.0, est=3.0263228579853076, details={'was_impossible': False}),
#  Prediction(uid=50, iid=424, r_ui=4.0, est=3.460163865518063, details={'was_impossible': False}),
#  Prediction(uid=50, iid=425, r_ui=4.0, est=3.9981612764856456, details={'was_impossible': False}),
#  Prediction(uid=50, iid=426, r_ui=4.0, est=3.438864379839594, details={'was_impossible': False}),
#  Prediction(uid=50, iid=427, r_ui=4.0, est=3.5899237288179884, details={'was_impossible': False}),
#  Prediction(uid=50, iid=428, r_ui=4.0, est=3.3693045067436156, details={'was_impossible': False}),
#  Prediction(uid=50, iid=429, r_ui=4.0, est=3.5391904720633365, details={'was_impossible': False}),
#  Prediction(uid=50, iid=430, r_ui=4.0, est=3.3545480149732896, details={'was_impossible': False}),
#  Prediction(uid=50, iid=431, r_ui=4.0, est=3.8023252009125206, details={'was_impossible': False}),
#  Prediction(uid=50, iid=432, r_ui=4.0, est=3.8092542613022857, details={'was_impossible': False}),
#  Prediction(uid=50, iid=433, r_ui=4.0, est=3.239602580409491, details={'was_impossible': False}),
#  Prediction(uid=50, iid=434, r_ui=4.0, est=3.7213384881048936, details={'was_impossible': False}),
#  Prediction(uid=50, iid=435, r_ui=4.0, est=3.713981647407252, details={'was_impossible': False}),
#  Prediction(uid=50, iid=436, r_ui=4.0, est=3.5790734376659414, details={'was_impossible': False}),
#  Prediction(uid=50, iid=437, r_ui=4.0, est=3.3426324594778065, details={'was_impossible': False}),
#  Prediction(uid=50, iid=438, r_ui=4.0, est=3.4683721009323696, details={'was_impossible': False}),
#  Prediction(uid=50, iid=439, r_ui=4.0, est=3.3784083380878545, details={'was_impossible': False}),
#  Prediction(uid=50, iid=440, r_ui=4.0, est=3.427830145827313, details={'was_impossible': False}),
#  Prediction(uid=50, iid=441, r_ui=4.0, est=2.804977513282339, details={'was_impossible': False}),
#  Prediction(uid=50, iid=442, r_ui=4.0, est=3.323253388836918, details={'was_impossible': False}),
#  Prediction(uid=50, iid=443, r_ui=4.0, est=3.610310909252657, details={'was_impossible': False}),
#  Prediction(uid=50, iid=444, r_ui=4.0, est=3.4371639254995783, details={'was_impossible': False}),
#  Prediction(uid=50, iid=445, r_ui=4.0, est=3.3899089071200206, details={'was_impossible': False}),
#  Prediction(uid=50, iid=446, r_ui=4.0, est=3.967489274160491, details={'was_impossible': False}),
#  Prediction(uid=50, iid=447, r_ui=4.0, est=3.6588005884450947, details={'was_impossible': False}),
#  Prediction(uid=50, iid=448, r_ui=4.0, est=3.577196310323198, details={'was_impossible': False}),
#  Prediction(uid=50, iid=449, r_ui=4.0, est=3.2940122027303826, details={'was_impossible': False}),
#  Prediction(uid=50, iid=450, r_ui=4.0, est=3.4154709000327106, details={'was_impossible': False}),
#  Prediction(uid=50, iid=451, r_ui=4.0, est=3.7961204818429097, details={'was_impossible': False}),
#  Prediction(uid=50, iid=452, r_ui=4.0, est=3.2622180845111237, details={'was_impossible': False}),
#  Prediction(uid=50, iid=453, r_ui=4.0, est=2.812642679246755, details={'was_impossible': False}),
#  Prediction(uid=50, iid=454, r_ui=4.0, est=3.636845404849178, details={'was_impossible': False}),
#  Prediction(uid=50, iid=455, r_ui=4.0, est=3.7651037966326752, details={'was_impossible': False}),
#  Prediction(uid=50, iid=456, r_ui=4.0, est=3.8299449918823747, details={'was_impossible': False}),
#  Prediction(uid=50, iid=457, r_ui=4.0, est=3.379427464557388, details={'was_impossible': False}),
#  Prediction(uid=50, iid=458, r_ui=4.0, est=3.755331326952172, details={'was_impossible': False}),
#  Prediction(uid=50, iid=459, r_ui=4.0, est=3.3693343174914356, details={'was_impossible': False}),
#  Prediction(uid=50, iid=460, r_ui=4.0, est=3.8408927736387093, details={'was_impossible': False}),
#  Prediction(uid=50, iid=461, r_ui=4.0, est=2.8170446043188893, details={'was_impossible': False}),
#  Prediction(uid=50, iid=462, r_ui=4.0, est=3.5287471318101327, details={'was_impossible': False}),
#  Prediction(uid=50, iid=463, r_ui=4.0, est=3.4917079977754586, details={'was_impossible': False}),
#  Prediction(uid=50, iid=464, r_ui=4.0, est=3.8578559003349935, details={'was_impossible': False}),
#  Prediction(uid=50, iid=465, r_ui=4.0, est=3.8948514486473735, details={'was_impossible': False}),
#  Prediction(uid=50, iid=466, r_ui=4.0, est=3.619235173518568, details={'was_impossible': False}),
#  Prediction(uid=50, iid=467, r_ui=4.0, est=3.2635139745615414, details={'was_impossible': False}),
#  Prediction(uid=50, iid=468, r_ui=4.0, est=3.4900997588614064, details={'was_impossible': False}),
#  Prediction(uid=50, iid=469, r_ui=4.0, est=3.496038397880797, details={'was_impossible': False}),
#  Prediction(uid=50, iid=470, r_ui=4.0, est=3.411843526559952, details={'was_impossible': False}),
#  Prediction(uid=50, iid=471, r_ui=4.0, est=3.5364422775893547, details={'was_impossible': False}),
#  Prediction(uid=50, iid=472, r_ui=4.0, est=3.340932993892469, details={'was_impossible': False}),
#  Prediction(uid=50, iid=473, r_ui=4.0, est=3.6529434975497463, details={'was_impossible': False}),
#  Prediction(uid=50, iid=474, r_ui=4.0, est=3.0941489959551722, details={'was_impossible': False}),
#  Prediction(uid=50, iid=475, r_ui=4.0, est=3.712895553756615, details={'was_impossible': False}),
#  Prediction(uid=50, iid=476, r_ui=4.0, est=3.8428105121946063, details={'was_impossible': False}),
#  Prediction(uid=50, iid=477, r_ui=4.0, est=3.5784156567381267, details={'was_impossible': False}),
#  Prediction(uid=50, iid=478, r_ui=4.0, est=3.568461474579057, details={'was_impossible': False}),
#  Prediction(uid=50, iid=479, r_ui=4.0, est=3.795256135192166, details={'was_impossible': False}),
#  Prediction(uid=50, iid=480, r_ui=4.0, est=3.56940807290835, details={'was_impossible': False}),
#  Prediction(uid=50, iid=481, r_ui=4.0, est=3.466466728432458, details={'was_impossible': False}),
#  Prediction(uid=50, iid=482, r_ui=4.0, est=3.242471182018212, details={'was_impossible': False}),
#  Prediction(uid=50, iid=483, r_ui=4.0, est=3.557008676923818, details={'was_impossible': False}),
#  Prediction(uid=50, iid=484, r_ui=4.0, est=3.852380826122118, details={'was_impossible': False}),
#  Prediction(uid=50, iid=485, r_ui=4.0, est=3.479298195184887, details={'was_impossible': False}),
#  Prediction(uid=50, iid=486, r_ui=4.0, est=3.8131168262955226, details={'was_impossible': False}),
#  Prediction(uid=50, iid=487, r_ui=4.0, est=3.6984815384172967, details={'was_impossible': False}),
#  Prediction(uid=50, iid=488, r_ui=4.0, est=3.6459331451177284, details={'was_impossible': False}),
#  Prediction(uid=50, iid=489, r_ui=4.0, est=2.989475173602217, details={'was_impossible': False}),
#  Prediction(uid=50, iid=490, r_ui=4.0, est=3.150993251927397, details={'was_impossible': False}),
#  Prediction(uid=50, iid=491, r_ui=4.0, est=3.4084931986527462, details={'was_impossible': False}),
#  Prediction(uid=50, iid=492, r_ui=4.0, est=3.4567276620131397, details={'was_impossible': False}),
#  Prediction(uid=50, iid=493, r_ui=4.0, est=3.3349981408938074, details={'was_impossible': False}),
#  Prediction(uid=50, iid=494, r_ui=4.0, est=3.6113733876237504, details={'was_impossible': False}),
#  Prediction(uid=50, iid=495, r_ui=4.0, est=3.276183645124363, details={'was_impossible': False}),
#  Prediction(uid=50, iid=496, r_ui=4.0, est=3.462591534906876, details={'was_impossible': False}),
#  Prediction(uid=50, iid=497, r_ui=4.0, est=3.504664856680865, details={'was_impossible': False}),
#  Prediction(uid=50, iid=498, r_ui=4.0, est=3.1669095527215694, details={'was_impossible': False}),
#  Prediction(uid=50, iid=499, r_ui=4.0, est=3.1207020713060807, details={'was_impossible': False}),
#  Prediction(uid=50, iid=500, r_ui=4.0, est=3.560683470482834, details={'was_impossible': False}),
#  Prediction(uid=50, iid=501, r_ui=4.0, est=3.6123782939587743, details={'was_impossible': False}),
#  Prediction(uid=50, iid=502, r_ui=4.0, est=3.7486508373576317, details={'was_impossible': False}),
#  Prediction(uid=50, iid=503, r_ui=4.0, est=3.605503721307237, details={'was_impossible': False}),
#  Prediction(uid=50, iid=504, r_ui=4.0, est=3.1663129351867996, details={'was_impossible': False}),
#  Prediction(uid=50, iid=505, r_ui=4.0, est=3.3176954844523214, details={'was_impossible': False}),
#  Prediction(uid=50, iid=506, r_ui=4.0, est=3.1720230805043954, details={'was_impossible': False}),
#  Prediction(uid=50, iid=507, r_ui=4.0, est=3.374271977235072, details={'was_impossible': False}),
#  Prediction(uid=50, iid=508, r_ui=4.0, est=3.7665740601286046, details={'was_impossible': False}),
#  Prediction(uid=50, iid=509, r_ui=4.0, est=3.458961962278274, details={'was_impossible': False}),
#  Prediction(uid=50, iid=510, r_ui=4.0, est=2.9685743170692795, details={'was_impossible': False}),
#  Prediction(uid=50, iid=511, r_ui=4.0, est=3.8960344521926538, details={'was_impossible': False}),
#  Prediction(uid=50, iid=512, r_ui=4.0, est=3.7344461124563217, details={'was_impossible': False}),
#  Prediction(uid=50, iid=513, r_ui=4.0, est=3.807783980788211, details={'was_impossible': False}),
#  Prediction(uid=50, iid=514, r_ui=4.0, est=3.7107609263594235, details={'was_impossible': False}),
#  Prediction(uid=50, iid=515, r_ui=4.0, est=3.3962609817422, details={'was_impossible': False}),
#  Prediction(uid=50, iid=516, r_ui=4.0, est=3.6283326966499816, details={'was_impossible': False}),
#  Prediction(uid=50, iid=517, r_ui=4.0, est=3.392222895069618, details={'was_impossible': False}),
#  Prediction(uid=50, iid=518, r_ui=4.0, est=3.551086521440198, details={'was_impossible': False}),
#  Prediction(uid=50, iid=519, r_ui=4.0, est=3.8427414735684633, details={'was_impossible': False}),
#  Prediction(uid=50, iid=520, r_ui=4.0, est=3.7922616806587577, details={'was_impossible': False}),
#  Prediction(uid=50, iid=521, r_ui=4.0, est=3.9767526266101627, details={'was_impossible': False}),
#  Prediction(uid=50, iid=522, r_ui=4.0, est=3.694125273793718, details={'was_impossible': False}),
#  Prediction(uid=50, iid=523, r_ui=4.0, est=2.795937607883013, details={'was_impossible': False}),
#  Prediction(uid=50, iid=524, r_ui=4.0, est=3.501243281857264, details={'was_impossible': False}),
#  Prediction(uid=50, iid=525, r_ui=4.0, est=3.9604562036240996, details={'was_impossible': False}),
#  Prediction(uid=50, iid=526, r_ui=4.0, est=3.639477351619893, details={'was_impossible': False}),
#  Prediction(uid=50, iid=527, r_ui=4.0, est=3.540200106684347, details={'was_impossible': False}),
# ...
#  Prediction(uid=50, iid=878, r_ui=4.0, est=3.546676060954834, details={'was_impossible': False}),
#  Prediction(uid=50, iid=879, r_ui=4.0, est=3.0943223699461586, details={'was_impossible': False}),
#  Prediction(uid=50, iid=880, r_ui=4.0, est=3.569623693558145, details={'was_impossible': False}),
#  Prediction(uid=50, iid=881, r_ui=4.0, est=3.484450134733732, details={'was_impossible': False}),
#  Prediction(uid=50, iid=882, r_ui=4.0, est=3.0649237191858933, details={'was_impossible': False}),
#  Prediction(uid=50, iid=883, r_ui=4.0, est=3.625008322302669, details={'was_impossible': False}),
#  Prediction(uid=50, iid=884, r_ui=4.0, est=3.207453979276035, details={'was_impossible': False}),
#  Prediction(uid=50, iid=885, r_ui=4.0, est=3.565743947281014, details={'was_impossible': False}),
#  Prediction(uid=50, iid=886, r_ui=4.0, est=3.39397495704974, details={'was_impossible': False}),
#  Prediction(uid=50, iid=887, r_ui=4.0, est=3.7498765278623996, details={'was_impossible': False}),
#  Prediction(uid=50, iid=888, r_ui=4.0, est=3.780308395362186, details={'was_impossible': False}),
#  Prediction(uid=50, iid=889, r_ui=4.0, est=3.292803760138129, details={'was_impossible': False}),
#  Prediction(uid=50, iid=890, r_ui=4.0, est=3.5245783429275916, details={'was_impossible': False}),
#  Prediction(uid=50, iid=891, r_ui=4.0, est=3.6538207502627493, details={'was_impossible': False}),
#  Prediction(uid=50, iid=892, r_ui=4.0, est=3.525201111777411, details={'was_impossible': False}),
#  Prediction(uid=50, iid=893, r_ui=4.0, est=3.5826051006222457, details={'was_impossible': False}),
#  Prediction(uid=50, iid=894, r_ui=4.0, est=3.7125923566650125, details={'was_impossible': False}),
#  Prediction(uid=50, iid=895, r_ui=4.0, est=3.3806285394302344, details={'was_impossible': False}),
#  Prediction(uid=50, iid=896, r_ui=4.0, est=3.395774420755874, details={'was_impossible': False}),
#  Prediction(uid=50, iid=897, r_ui=4.0, est=3.260899525232809, details={'was_impossible': False}),
#  Prediction(uid=50, iid=898, r_ui=4.0, est=3.5534227103248344, details={'was_impossible': False}),
#  Prediction(uid=50, iid=899, r_ui=4.0, est=3.529768078940948, details={'was_impossible': False}),
#  Prediction(uid=50, iid=900, r_ui=4.0, est=3.594758020409642, details={'was_impossible': False}),
#  Prediction(uid=50, iid=901, r_ui=4.0, est=3.50840281921847, details={'was_impossible': False}),
#  Prediction(uid=50, iid=902, r_ui=4.0, est=3.416888223475625, details={'was_impossible': False}),
#  Prediction(uid=50, iid=903, r_ui=4.0, est=3.419840635198655, details={'was_impossible': False}),
#  Prediction(uid=50, iid=904, r_ui=4.0, est=3.359933668700987, details={'was_impossible': False}),
#  Prediction(uid=50, iid=905, r_ui=4.0, est=3.4227598120251814, details={'was_impossible': False}),
#  Prediction(uid=50, iid=906, r_ui=4.0, est=3.3089422260134986, details={'was_impossible': False}),
#  Prediction(uid=50, iid=907, r_ui=4.0, est=3.3495432454064558, details={'was_impossible': False}),
#  Prediction(uid=50, iid=908, r_ui=4.0, est=3.5352191702060325, details={'was_impossible': False}),
#  Prediction(uid=50, iid=909, r_ui=4.0, est=3.178472069304149, details={'was_impossible': False}),
#  Prediction(uid=50, iid=910, r_ui=4.0, est=3.615750181563974, details={'was_impossible': False}),
#  Prediction(uid=50, iid=911, r_ui=4.0, est=3.4976162390792274, details={'was_impossible': False}),
#  Prediction(uid=50, iid=912, r_ui=4.0, est=3.585583255042592, details={'was_impossible': False}),
#  Prediction(uid=50, iid=913, r_ui=4.0, est=3.546034048282729, details={'was_impossible': False}),
#  Prediction(uid=50, iid=914, r_ui=4.0, est=3.5318021764055727, details={'was_impossible': False}),
#  Prediction(uid=50, iid=915, r_ui=4.0, est=3.560542627949489, details={'was_impossible': False}),
#  Prediction(uid=50, iid=916, r_ui=4.0, est=3.4789714729474355, details={'was_impossible': False}),
#  Prediction(uid=50, iid=917, r_ui=4.0, est=3.6724180372773563, details={'was_impossible': False}),
#  Prediction(uid=50, iid=918, r_ui=4.0, est=3.710871137168618, details={'was_impossible': False}),
#  Prediction(uid=50, iid=919, r_ui=4.0, est=3.2814631776037864, details={'was_impossible': False}),
#  Prediction(uid=50, iid=920, r_ui=4.0, est=3.6483376433791648, details={'was_impossible': False}),
#  Prediction(uid=50, iid=921, r_ui=4.0, est=3.3649742375937666, details={'was_impossible': False}),
#  Prediction(uid=50, iid=922, r_ui=4.0, est=3.7675754320786807, details={'was_impossible': False}),
#  Prediction(uid=50, iid=923, r_ui=4.0, est=3.026949416650605, details={'was_impossible': False}),
#  Prediction(uid=50, iid=924, r_ui=4.0, est=3.097345523119678, details={'was_impossible': False}),
#  Prediction(uid=50, iid=925, r_ui=4.0, est=3.2003792757324407, details={'was_impossible': False}),
#  Prediction(uid=50, iid=926, r_ui=4.0, est=3.4535440873962764, details={'was_impossible': False}),
#  Prediction(uid=50, iid=927, r_ui=4.0, est=3.310854525441561, details={'was_impossible': False}),
#  Prediction(uid=50, iid=928, r_ui=4.0, est=3.3397385284211274, details={'was_impossible': False}),
#  Prediction(uid=50, iid=929, r_ui=4.0, est=3.399280649324092, details={'was_impossible': False}),
#  Prediction(uid=50, iid=930, r_ui=4.0, est=2.9885164296721776, details={'was_impossible': False}),
#  Prediction(uid=50, iid=931, r_ui=4.0, est=3.3663585679909707, details={'was_impossible': False}),
#  Prediction(uid=50, iid=932, r_ui=4.0, est=3.202426604712319, details={'was_impossible': False}),
#  Prediction(uid=50, iid=933, r_ui=4.0, est=3.0884169875710232, details={'was_impossible': False}),
#  Prediction(uid=50, iid=934, r_ui=4.0, est=3.302182151991434, details={'was_impossible': False}),
#  Prediction(uid=50, iid=935, r_ui=4.0, est=3.1080264247102285, details={'was_impossible': False}),
#  Prediction(uid=50, iid=936, r_ui=4.0, est=3.7355688607953432, details={'was_impossible': False}),
#  Prediction(uid=50, iid=937, r_ui=4.0, est=3.6485984721937976, details={'was_impossible': False}),
#  Prediction(uid=50, iid=938, r_ui=4.0, est=3.364891717030278, details={'was_impossible': False}),
#  Prediction(uid=50, iid=939, r_ui=4.0, est=3.656892187890836, details={'was_impossible': False}),
#  Prediction(uid=50, iid=940, r_ui=4.0, est=3.897266964567657, details={'was_impossible': False}),
#  Prediction(uid=50, iid=941, r_ui=4.0, est=3.104866113614692, details={'was_impossible': False}),
#  Prediction(uid=50, iid=942, r_ui=4.0, est=3.386524005848477, details={'was_impossible': False}),
#  Prediction(uid=50, iid=943, r_ui=4.0, est=3.4321863579852026, details={'was_impossible': False}),
#  Prediction(uid=50, iid=944, r_ui=4.0, est=3.3081521347609724, details={'was_impossible': False}),
#  Prediction(uid=50, iid=945, r_ui=4.0, est=3.413143587097198, details={'was_impossible': False}),
#  Prediction(uid=50, iid=946, r_ui=4.0, est=3.383036460924325, details={'was_impossible': False}),
#  Prediction(uid=50, iid=947, r_ui=4.0, est=3.2864262187119495, details={'was_impossible': False}),
#  Prediction(uid=50, iid=948, r_ui=4.0, est=3.6384477992148447, details={'was_impossible': False}),
#  Prediction(uid=50, iid=949, r_ui=4.0, est=3.3572925845784387, details={'was_impossible': False}),
#  Prediction(uid=50, iid=950, r_ui=4.0, est=3.428739276222819, details={'was_impossible': False}),
#  Prediction(uid=50, iid=951, r_ui=4.0, est=2.9084538264821544, details={'was_impossible': False}),
#  Prediction(uid=50, iid=952, r_ui=4.0, est=3.5823769029416326, details={'was_impossible': False}),
#  Prediction(uid=50, iid=953, r_ui=4.0, est=3.5475347402716837, details={'was_impossible': False}),
#  Prediction(uid=50, iid=954, r_ui=4.0, est=3.4280702004266104, details={'was_impossible': False}),
#  Prediction(uid=50, iid=955, r_ui=4.0, est=3.169550643505759, details={'was_impossible': False}),
#  Prediction(uid=50, iid=956, r_ui=4.0, est=3.433219763878734, details={'was_impossible': False}),
#  Prediction(uid=50, iid=957, r_ui=4.0, est=3.550066987959094, details={'was_impossible': False}),
#  Prediction(uid=50, iid=958, r_ui=4.0, est=3.444651056319432, details={'was_impossible': False}),
#  Prediction(uid=50, iid=959, r_ui=4.0, est=3.425183921798977, details={'was_impossible': False}),
#  Prediction(uid=50, iid=960, r_ui=4.0, est=3.272364214197826, details={'was_impossible': False}),
#  Prediction(uid=50, iid=961, r_ui=4.0, est=3.4416680456758946, details={'was_impossible': False}),
#  Prediction(uid=50, iid=962, r_ui=4.0, est=3.55130369790617, details={'was_impossible': False}),
#  Prediction(uid=50, iid=963, r_ui=4.0, est=3.5469085231665116, details={'was_impossible': False}),
#  Prediction(uid=50, iid=964, r_ui=4.0, est=3.4586620025555845, details={'was_impossible': False}),
#  Prediction(uid=50, iid=965, r_ui=4.0, est=3.441653182018337, details={'was_impossible': False}),
#  Prediction(uid=50, iid=966, r_ui=4.0, est=3.4605502082596376, details={'was_impossible': False}),
#  Prediction(uid=50, iid=967, r_ui=4.0, est=3.3406443557622225, details={'was_impossible': False}),
#  Prediction(uid=50, iid=968, r_ui=4.0, est=3.6429317372728254, details={'was_impossible': False}),
#  Prediction(uid=50, iid=969, r_ui=4.0, est=3.4590047690466643, details={'was_impossible': False}),
#  Prediction(uid=50, iid=970, r_ui=4.0, est=3.471239629157915, details={'was_impossible': False}),
#  Prediction(uid=50, iid=971, r_ui=4.0, est=3.3412984357232, details={'was_impossible': False}),
#  Prediction(uid=50, iid=972, r_ui=4.0, est=3.502775634231536, details={'was_impossible': False}),
#  Prediction(uid=50, iid=973, r_ui=4.0, est=3.499656669178859, details={'was_impossible': False}),
#  Prediction(uid=50, iid=974, r_ui=4.0, est=3.266203317316887, details={'was_impossible': False}),
#  Prediction(uid=50, iid=975, r_ui=4.0, est=3.3767572682957154, details={'was_impossible': False}),
#  Prediction(uid=50, iid=976, r_ui=4.0, est=3.5577394161624363, details={'was_impossible': False}),
#  Prediction(uid=50, iid=977, r_ui=4.0, est=3.6984738769038383, details={'was_impossible': False}),
#  Prediction(uid=50, iid=978, r_ui=4.0, est=3.1144349863179426, details={'was_impossible': False}),
#  Prediction(uid=50, iid=979, r_ui=4.0, est=3.5257025488675158, details={'was_impossible': False}),
#  Prediction(uid=50, iid=980, r_ui=4.0, est=3.453310591003637, details={'was_impossible': False}),
#  Prediction(uid=50, iid=981, r_ui=4.0, est=3.5143215460627255, details={'was_impossible': False}),
#  Prediction(uid=50, iid=982, r_ui=4.0, est=3.272963626833566, details={'was_impossible': False}),
#  Prediction(uid=50, iid=983, r_ui=4.0, est=3.170018602125583, details={'was_impossible': False}),
#  Prediction(uid=50, iid=984, r_ui=4.0, est=3.2552922822028947, details={'was_impossible': False}),
#  Prediction(uid=50, iid=985, r_ui=4.0, est=3.231066540062583, details={'was_impossible': False}),
#  Prediction(uid=50, iid=986, r_ui=4.0, est=3.5235030154991716, details={'was_impossible': False}),
#  Prediction(uid=50, iid=987, r_ui=4.0, est=3.4829064468348805, details={'was_impossible': False}),
#  Prediction(uid=50, iid=988, r_ui=4.0, est=3.504903454169745, details={'was_impossible': False}),
#  Prediction(uid=50, iid=989, r_ui=4.0, est=3.270145447961081, details={'was_impossible': False}),
#  Prediction(uid=50, iid=990, r_ui=4.0, est=3.3696744187900025, details={'was_impossible': False}),
#  Prediction(uid=50, iid=991, r_ui=4.0, est=3.231578698378579, details={'was_impossible': False}),
#  Prediction(uid=50, iid=992, r_ui=4.0, est=3.483083305924863, details={'was_impossible': False}),
#  Prediction(uid=50, iid=993, r_ui=4.0, est=3.2791684079047685, details={'was_impossible': False}),
#  Prediction(uid=50, iid=994, r_ui=4.0, est=3.521644964681194, details={'was_impossible': False}),
#  Prediction(uid=50, iid=995, r_ui=4.0, est=3.4074270210134, details={'was_impossible': False}),
#  Prediction(uid=50, iid=996, r_ui=4.0, est=3.244357480649188, details={'was_impossible': False}),
#  Prediction(uid=50, iid=997, r_ui=4.0, est=3.371713708194422, details={'was_impossible': False}),
#  Prediction(uid=50, iid=998, r_ui=4.0, est=3.421014928940065, details={'was_impossible': False}),
#  Prediction(uid=50, iid=999, r_ui=4.0, est=3.55363686639449, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1000, r_ui=4.0, est=3.4088234780292535, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1001, r_ui=4.0, est=3.7135344549364846, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1002, r_ui=4.0, est=3.672693789551647, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1003, r_ui=4.0, est=2.740198255894154, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1004, r_ui=4.0, est=3.444401254887499, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1005, r_ui=4.0, est=3.351561488047728, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1006, r_ui=4.0, est=3.333811722615191, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1007, r_ui=4.0, est=3.445879876109637, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1008, r_ui=4.0, est=3.1872805369594976, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1009, r_ui=4.0, est=3.2456408195437, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1010, r_ui=4.0, est=3.6441922912152833, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1011, r_ui=4.0, est=3.613412782894948, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1012, r_ui=4.0, est=3.473956456961196, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1013, r_ui=4.0, est=3.4409399685851487, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1014, r_ui=4.0, est=3.5195383945797336, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1015, r_ui=4.0, est=3.6748025108055637, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1016, r_ui=4.0, est=3.2995602495798333, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1017, r_ui=4.0, est=3.277533303579813, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1018, r_ui=4.0, est=3.724678482006354, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1019, r_ui=4.0, est=3.3230944002190648, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1020, r_ui=4.0, est=3.2826767263962013, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1021, r_ui=4.0, est=3.1792950362610957, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1022, r_ui=4.0, est=3.2116969839494316, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1023, r_ui=4.0, est=3.4845872813108265, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1024, r_ui=4.0, est=3.4482079492269517, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1025, r_ui=4.0, est=3.539946049289963, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1026, r_ui=4.0, est=3.5461674804977785, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1027, r_ui=4.0, est=3.700595730729059, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1028, r_ui=4.0, est=3.179930424528162, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1029, r_ui=4.0, est=3.6803695277854156, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1030, r_ui=4.0, est=3.4637256199781183, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1031, r_ui=4.0, est=3.58548803605564, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1032, r_ui=4.0, est=3.6051708491250003, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1033, r_ui=4.0, est=3.402225445183919, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1034, r_ui=4.0, est=3.1830299323911864, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1035, r_ui=4.0, est=3.3605979024799946, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1036, r_ui=4.0, est=3.669772031692874, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1037, r_ui=4.0, est=3.1385260197316165, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1038, r_ui=4.0, est=3.527467853851023, details={'was_impossible': False}),
#  Prediction(uid=50, iid=1039, r_ui=4.0, est=3.5695583106779023, details={'was_impossible': False}),
#  ...]

# %%
#As you can see from the output, each prediction is a special object. In order to find the best, we’ll convert this object into an array of the predicted ratings. 
#We’ll then use this to find the iid with the best predicted rating.

# %%
pred_ratings = np.array([pred.est for pred in predictions])

# %%
#Find the index of maximum predicted rating
i_max = pred_ratings.argmax()

# %%
#Find maximum rating iids to recommand
iids = iids_to_pred[i_max]

# %%
print('Top item for user 50 has iid {0} with predicted rating {1}'.format(iids,pred_ratings[i_max]))
# Out:
# Top item for user 50 has iid 286 with predicted rating 4.0

# %%
#Similarly you can get the top n items for user 50, just replace the argmax() method with the argpartition()

# %%
i_max = pred_ratings.argpartition(10)

# %%
i_max
# Out:
# array([ 703,  547,  660, ...,    2, 2030, 1015], dtype=int64)

# %%
#Find maximum rating iids to recommand
iids = iids_to_pred[i_max]

# %%
iids
# Out:
# array([ 743,  587,  700, ...,   16, 2070, 1055], dtype=int64)

# %%
for i in iids:
    print('Top item for user 50 has iid {0} with predicted rating {1}'.format(i,pred_ratings[i]))
# Out:
# Top item for user 50 has iid 743 with predicted rating 3.4350174446647537
# Top item for user 50 has iid 587 with predicted rating 3.4910704151242835
# Top item for user 50 has iid 700 with predicted rating 3.3825265160874767
# Top item for user 50 has iid 734 with predicted rating 3.5957441146796043
# Top item for user 50 has iid 592 with predicted rating 3.584955824973685
# Top item for user 50 has iid 676 with predicted rating 3.4218632745892044
# Top item for user 50 has iid 832 with predicted rating 3.167859185270481
# Top item for user 50 has iid 100 with predicted rating 3.083223487546837
# Top item for user 50 has iid 1003 with predicted rating 3.3105031331885466
# Top item for user 50 has iid 523 with predicted rating 3.917377626638785
# Top item for user 50 has iid 441 with predicted rating 3.466466728432458
# Top item for user 50 has iid 243 with predicted rating 3.07176659692632
# Top item for user 50 has iid 453 with predicted rating 3.3349981408938074
# Top item for user 50 has iid 461 with predicted rating 3.6123782939587743
# Top item for user 50 has iid 724 with predicted rating 3.687048564296813
# Top item for user 50 has iid 719 with predicted rating 3.2195516314590535
# Top item for user 50 has iid 1357 with predicted rating 3.2675036214283897
# Top item for user 50 has iid 1054 with predicted rating 3.5231998368775455
# Top item for user 50 has iid 742 with predicted rating 3.4475932710696178
# Top item for user 50 has iid 594 with predicted rating 3.5334617123649554
# Top item for user 50 has iid 597 with predicted rating 3.6306640287098344
# Top item for user 50 has iid 721 with predicted rating 3.5276901292273486
# Top item for user 50 has iid 169 with predicted rating 3.6176694533989093
# Top item for user 50 has iid 694 with predicted rating 2.596877381748526
# Top item for user 50 has iid 70 with predicted rating 3.5600436022698347
# Top item for user 50 has iid 951 with predicted rating 3.231578698378579
# Top item for user 50 has iid 1384 with predicted rating 3.4039735212803746
# Top item for user 50 has iid 751 with predicted rating 3.3838553338508115
# Top item for user 50 has iid 756 with predicted rating 3.727344367785172
# Top item for user 50 has iid 1249 with predicted rating 3.4661435178949658
# Top item for user 50 has iid 326 with predicted rating 3.482557314537238
# Top item for user 50 has iid 1109 with predicted rating 3.4398063079755805
# Top item for user 50 has iid 591 with predicted rating 3.2233112056980904
# Top item for user 50 has iid 510 with predicted rating 3.771602292614923
# Top item for user 50 has iid 930 with predicted rating 3.471239629157915
# Top item for user 50 has iid 489 with predicted rating 3.2502975051491085
# Top item for user 50 has iid 364 with predicted rating 3.32913641496309
# Top item for user 50 has iid 1095 with predicted rating 3.532063572056407
# Top item for user 50 has iid 1342 with predicted rating 2.9617073747970744
# Top item for user 50 has iid 1654 with predicted rating 3.7435539047197954
# Top item for user 50 has iid 156 with predicted rating 3.24261122421599
# Top item for user 50 has iid 1527 with predicted rating 3.611397384514793
# Top item for user 50 has iid 1382 with predicted rating 3.686177595814745
# Top item for user 50 has iid 351 with predicted rating 3.9474473770935856
# Top item for user 50 has iid 586 with predicted rating 3.461333664352404
# Top item for user 50 has iid 541 with predicted rating 3.2906879466352756
# Top item for user 50 has iid 383 with predicted rating 3.0263228579853076
# Top item for user 50 has iid 389 with predicted rating 3.5391904720633365
# Top item for user 50 has iid 1569 with predicted rating 3.4501287697039023
# Top item for user 50 has iid 1337 with predicted rating 3.3398653391454944
# Top item for user 50 has iid 113 with predicted rating 3.3450797033043393
# Top item for user 50 has iid 882 with predicted rating 3.7675754320786807
# Top item for user 50 has iid 1441 with predicted rating 3.7916434026182793
# Top item for user 50 has iid 341 with predicted rating 3.1167127718403997
# Top item for user 50 has iid 1120 with predicted rating 3.4859036266026835
# Top item for user 50 has iid 263 with predicted rating 3.5024980034371147
# Top item for user 50 has iid 923 with predicted rating 3.5469085231665116
# Top item for user 50 has iid 1200 with predicted rating 3.350751786960327
# Top item for user 50 has iid 36 with predicted rating 3.4231871848048785
# Top item for user 50 has iid 691 with predicted rating 3.4629343269364417
# Top item for user 50 has iid 1318 with predicted rating 3.4019447384207058
# Top item for user 50 has iid 628 with predicted rating 3.3377677015251046
# Top item for user 50 has iid 1387 with predicted rating 3.3634535021198766
# Top item for user 50 has iid 749 with predicted rating 3.486738832348827
# Top item for user 50 has iid 1218 with predicted rating 3.465543787855957
# Top item for user 50 has iid 1210 with predicted rating 3.2753060520382875
# Top item for user 50 has iid 423 with predicted rating 3.4917079977754586
# Top item for user 50 has iid 820 with predicted rating 3.4429629918244897
# Top item for user 50 has iid 116 with predicted rating 3.547972383084315
# Top item for user 50 has iid 184 with predicted rating 3.4512509460647554
# Top item for user 50 has iid 698 with predicted rating 3.2732698645133387
# Top item for user 50 has iid 779 with predicted rating 3.712570635880487
# Top item for user 50 has iid 1582 with predicted rating 3.5174770798787343
# Top item for user 50 has iid 1202 with predicted rating 3.324456893275002
# Top item for user 50 has iid 385 with predicted rating 3.9981612764856456
# Top item for user 50 has iid 1108 with predicted rating 3.4041666112258917
# Top item for user 50 has iid 941 with predicted rating 3.5143215460627255
# Top item for user 50 has iid 579 with predicted rating 3.513268671317804
# Top item for user 50 has iid 474 with predicted rating 3.7107609263594235
# Top item for user 50 has iid 1272 with predicted rating 3.3045693478029357
# Top item for user 50 has iid 1543 with predicted rating 3.55837544487021
# Top item for user 50 has iid 935 with predicted rating 3.3767572682957154
# Top item for user 50 has iid 557 with predicted rating 2.9296938294207613
# Top item for user 50 has iid 933 with predicted rating 3.499656669178859
# Top item for user 50 has iid 283 with predicted rating 3.2791100893515908
# Top item for user 50 has iid 924 with predicted rating 3.4586620025555845
# Top item for user 50 has iid 1235 with predicted rating 3.5929414398088655
# Top item for user 50 has iid 277 with predicted rating 3.3395486999735478
# Top item for user 50 has iid 862 with predicted rating 3.416888223475625
# Top item for user 50 has iid 879 with predicted rating 3.2814631776037864
# Top item for user 50 has iid 1311 with predicted rating 3.4392395602814276
# Top item for user 50 has iid 1939 with predicted rating 3.4601372957171317
# Top item for user 50 has iid 978 with predicted rating 3.724678482006354
# Top item for user 50 has iid 1943 with predicted rating 3.5435722979372306
# Top item for user 50 has iid 1938 with predicted rating 3.447197457426521
# Top item for user 50 has iid 159 with predicted rating 3.366340476113491
# Top item for user 50 has iid 1060 with predicted rating 3.538252680449779
# Top item for user 50 has iid 1956 with predicted rating 3.469059980714778
# Top item for user 50 has iid 175 with predicted rating 3.643103732861504
# Top item for user 50 has iid 179 with predicted rating 3.4125190539329004
# Top item for user 50 has iid 499 with predicted rating 3.5570201683433407
# Top item for user 50 has iid 1833 with predicted rating 3.640367731287062
# Top item for user 50 has iid 692 with predicted rating 3.7390420997220737
# Top item for user 50 has iid 1086 with predicted rating 3.3293659504992594
# Top item for user 50 has iid 381 with predicted rating 3.672732644783029
# Top item for user 50 has iid 387 with predicted rating 3.5899237288179884
# Top item for user 50 has iid 829 with predicted rating 3.4615862962082335
# Top item for user 50 has iid 14 with predicted rating 3.3767402458363005
# Top item for user 50 has iid 125 with predicted rating 3.783790415050468
# Top item for user 50 has iid 1237 with predicted rating 3.659747363194556
# Top item for user 50 has iid 1778 with predicted rating 3.380136402173188
# Top item for user 50 has iid 1037 with predicted rating 3.7149703989023455
# Top item for user 50 has iid 1767 with predicted rating 3.507749223959247
# Top item for user 50 has iid 1514 with predicted rating 3.1802983126593416
# Top item for user 50 has iid 1199 with predicted rating 3.240972639466346
# Top item for user 50 has iid 1334 with predicted rating 3.4708523144439654
# Top item for user 50 has iid 266 with predicted rating 3.6382394823144093
# Top item for user 50 has iid 1034 with predicted rating 3.4991107855341745
# Top item for user 50 has iid 1028 with predicted rating 3.7812581390977114
# Top item for user 50 has iid 759 with predicted rating 3.720711998781731
# Top item for user 50 has iid 1674 with predicted rating 3.3989350207964706
# Top item for user 50 has iid 760 with predicted rating 3.365913538108662
# Top item for user 50 has iid 1021 with predicted rating 3.377929473783198
# Top item for user 50 has iid 1670 with predicted rating 3.445099314610713
# Top item for user 50 has iid 1326 with predicted rating 3.598099922240067
# Top item for user 50 has iid 1338 with predicted rating 3.530468466986192
# Top item for user 50 has iid 1919 with predicted rating 3.616992809212128
# Top item for user 50 has iid 1050 with predicted rating 3.726602358478706
# Top item for user 50 has iid 1656 with predicted rating 3.4225832560147817
# Top item for user 50 has iid 765 with predicted rating 4.0
# Top item for user 50 has iid 354 with predicted rating 3.521542280568153
# Top item for user 50 has iid 727 with predicted rating 3.6400633077339153
# Top item for user 50 has iid 1645 with predicted rating 3.364369592130147
# Top item for user 50 has iid 1885 with predicted rating 3.681845745679443
# Top item for user 50 has iid 1940 with predicted rating 3.5251767132038343
# Top item for user 50 has iid 1882 with predicted rating 3.501959008522038
# Top item for user 50 has iid 722 with predicted rating 3.232423811927498
# Top item for user 50 has iid 1008 with predicted rating 3.5839240086228585
# Top item for user 50 has iid 720 with predicted rating 3.158796974722961
# Top item for user 50 has iid 1367 with predicted rating 3.305729310638397
# Top item for user 50 has iid 1640 with predicted rating 3.517966991403981
# Top item for user 50 has iid 361 with predicted rating 3.6025331478443716
# Top item for user 50 has iid 506 with predicted rating 3.4942435902069824
# Top item for user 50 has iid 1949 with predicted rating 3.3292848617796684
# Top item for user 50 has iid 1063 with predicted rating 3.570973154834242
# Top item for user 50 has iid 1298 with predicted rating 3.1679491462809044
# Top item for user 50 has iid 1290 with predicted rating 3.6631082584595624
# Top item for user 50 has iid 710 with predicted rating 3.7952532597795345
# Top item for user 50 has iid 1859 with predicted rating 3.5821221028303665
# Top item for user 50 has iid 708 with predicted rating 3.327951253313163
# Top item for user 50 has iid 569 with predicted rating 3.7119054567357557
# Top item for user 50 has iid 1952 with predicted rating 3.44180541520256
# Top item for user 50 has iid 504 with predicted rating 3.3955771555164307
# Top item for user 50 has iid 1271 with predicted rating 3.0950009138022754
# Top item for user 50 has iid 171 with predicted rating 3.6574311194384204
# Top item for user 50 has iid 575 with predicted rating 3.550128481029592
# Top item for user 50 has iid 1955 with predicted rating 3.56768649564685
# Top item for user 50 has iid 301 with predicted rating 3.032457038062643
# Top item for user 50 has iid 1375 with predicted rating 3.3964574625819375
# Top item for user 50 has iid 89 with predicted rating 3.5960549539284705
# Top item for user 50 has iid 1840 with predicted rating 3.6213919780891137
# Top item for user 50 has iid 584 with predicted rating 3.5681254178105637
# Top item for user 50 has iid 1611 with predicted rating 3.42465904971437
# Top item for user 50 has iid 1381 with predicted rating 3.4112020695638403
# Top item for user 50 has iid 585 with predicted rating 3.5780526963863113
# Top item for user 50 has iid 784 with predicted rating 3.5194855835602135
# Top item for user 50 has iid 1596 with predicted rating 3.4615132430954803
# Top item for user 50 has iid 498 with predicted rating 3.3571208906685106
# Top item for user 50 has iid 1966 with predicted rating 3.499309613933913
# Top item for user 50 has iid 76 with predicted rating 3.2460747898483167
# Top item for user 50 has iid 490 with predicted rating 3.7804418758947245
# Top item for user 50 has iid 1830 with predicted rating 3.453358003010724
# Top item for user 50 has iid 983 with predicted rating 3.4845872813108265
# Top item for user 50 has iid 1393 with predicted rating 3.5581169741879255
# Top item for user 50 has iid 1088 with predicted rating 3.5356186955800872
# Top item for user 50 has iid 688 with predicted rating 4.0
# Top item for user 50 has iid 687 with predicted rating 3.1885220680967774
# Top item for user 50 has iid 955 with predicted rating 3.4074270210134
# Top item for user 50 has iid 195 with predicted rating 3.330323976489049
# Top item for user 50 has iid 810 with predicted rating 3.7670322104174634
# Top item for user 50 has iid 685 with predicted rating 3.3018724074954493
# Top item for user 50 has iid 65 with predicted rating 3.3509157761908885
# Top item for user 50 has iid 1255 with predicted rating 3.5215700136132604
# Top item for user 50 has iid 1396 with predicted rating 3.7722794864035953
# Top item for user 50 has iid 63 with predicted rating 3.442817982723811
# Top item for user 50 has iid 1406 with predicted rating 3.6136851289001464
# Top item for user 50 has iid 2005 with predicted rating 3.8211564697096843
# Top item for user 50 has iid 1554 with predicted rating 3.646130544571304
# Top item for user 50 has iid 46 with predicted rating 3.5310072635089127
# Top item for user 50 has iid 208 with predicted rating 3.3691043974832424
# Top item for user 50 has iid 872 with predicted rating 3.585583255042592
# Top item for user 50 has iid 599 with predicted rating 3.3000935990610376
# Top item for user 50 has iid 1113 with predicted rating 3.6814685938821285
# Top item for user 50 has iid 932 with predicted rating 3.502775634231536
# Top item for user 50 has iid 608 with predicted rating 3.5812416497832316
# Top item for user 50 has iid 1124 with predicted rating 3.1962256132672855
# Top item for user 50 has iid 925 with predicted rating 3.441653182018337
# Top item for user 50 has iid 909 with predicted rating 3.3572925845784387
# Top item for user 50 has iid 224 with predicted rating 3.33179507486804
# Top item for user 50 has iid 407 with predicted rating 3.6588005884450947
# Top item for user 50 has iid 1234 with predicted rating 3.561993060290332
# Top item for user 50 has iid 1158 with predicted rating 3.818001671279992
# Top item for user 50 has iid 1164 with predicted rating 3.6495204470664877
# Top item for user 50 has iid 32 with predicted rating 3.278767585603403
# Top item for user 50 has iid 1785 with predicted rating 3.5672165730935297
# Top item for user 50 has iid 1756 with predicted rating 3.6460922135507583
# Top item for user 50 has iid 274 with predicted rating 3.4809108641517295
# Top item for user 50 has iid 237 with predicted rating 3.1052798126683765
# Top item for user 50 has iid 1224 with predicted rating 3.4773816403445936
# Top item for user 50 has iid 1166 with predicted rating 3.3812857859625263
# Top item for user 50 has iid 409 with predicted rating 3.2940122027303826
# Top item for user 50 has iid 853 with predicted rating 3.5826051006222457
# Top item for user 50 has iid 1483 with predicted rating 3.411871390856002
# Top item for user 50 has iid 1775 with predicted rating 3.4500617636786246
# Top item for user 50 has iid 1180 with predicted rating 3.5117851150101784
# Top item for user 50 has iid 248 with predicted rating 3.4988193083752663
# Top item for user 50 has iid 1183 with predicted rating 3.566593663908949
# Top item for user 50 has iid 631 with predicted rating 3.6488784574172635
# Top item for user 50 has iid 1772 with predicted rating 3.4331094114304617
# Top item for user 50 has iid 1216 with predicted rating 3.41653243278999
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-30-96c864c3fb61> in <module>
#       1 for i in iids:
# ----> 2     print('Top item for user 50 has iid {0} with predicted rating {1}'.format(i,pred_ratings[i]))
#
# IndexError: index 2051 is out of bounds for axis 0 with size 2032

# %% [markdown]
# As you probably already know, it is bad practice to fit a model on the whole dataset without checking its performance and tuning parameters which affect the fit. So for the remainder of the tutorial we’ll show you how to tune the parameters of SVD++ and evaluate the performance of the method. The method SVD++, as well as most other matrix factorisation algorithms, will depend on a number of main tuning constants: the dimension DD affecting the size of UU and VV; the learning rate, which affects the performance of the optimisation step; the regularisation term affecting the overfitting of the model; and the number of epochs, which determines how many iterations of optimisation are used.
# In this tutorial we’ll tune the learning rate and the regularisation term. SVD++ has more than one learning rate and regularisation term. But surprise lets a fixed value be set for all the learning rate values, and another for all the regularisation terms, so we'll do this for speed. In surprise, tuning is performed using a function called GridSearchCV, which picks the constants which perform the best at predicting a held out testset. This means constant values to try need to be predefined.
# First let’s define our list of constant values to check, typically the learning rate is a small value between 0 and 1. In theory, the regularisation parameter can be any positive real value, but in practice it is limited as setting it too small will result in overfitting, while setting it too large will result in poor performance; so trying a list of reasonable values should be fine. The GridSearchCV function can then be used to determine the best performing parameter values using cross validation. We've chosen quite a limited list since this code can take a while to run, as it has to fit multiple models with different parameters.

# %%
param_grid = {'lr_all':[.001,.01],'reg_all':[.1,.5]}
gs = surprise.model_selection.GridSearchCV(surprise.SVDpp,param_grid,measures=['rmse','mae'],cv=3)

# %%
gs.fit(data)

# %%
print(gs.best_params['rmse'])
# Out:
# {'lr_all': 0.01, 'reg_all': 0.1}

# %% [markdown]
# The output prints the combination of parameters that gets the best RMSE on a held out test set, RMSE is a way of measuring the prediction error. In this case, we’ve only checked a few tuning constant values, because these procedures can take a while to run. But typically you will try out as many values as possible to get the best performance you can.
# The performance of a particular model you’ve chosen can be evaluated using cross validation. This might be used to compare a number of methods for example, or just to check your method is performing reasonably. This can be done by running the following:

# %%
alg = surprise.SVDpp(lr_all=.001,reg_all=0.1)

# %%
output = surprise.model_selection.cross_validate(alg, data, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVDpp on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8245  0.8362  0.8248  0.8382  0.8260  0.8299  0.0060
# MAE (testset)     0.6525  0.6602  0.6550  0.6628  0.6556  0.6572  0.0037
# Fit time          15.65   20.69   27.38   36.70   20.92   24.27   7.25
# Test time         0.30    0.63    1.36    0.37    0.36    0.61    0.40
